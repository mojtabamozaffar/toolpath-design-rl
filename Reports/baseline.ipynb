# %%
import numpy as np
from plot import plot_result_csv, plot_result_event

# %% [markdown]
# ## BASELINE
# There are two baselines, which are named as 'new_section_baseline' and 'baseline'. But their parameters (root_dirichlet_alpha, root_exploration_fraction, temperature?) are different.
# ### new_section_baseline
# |parameters|value|
# |:---|:---|
# |observation_shape|(1,32,32)|
# |action_space_size|4|
# |max_moves|400|
# |support_size_value|20|
# |support_size_reward|1|
# |num_simulations|50|
# |discount|0.997|
# |temperature_threshold|300|
# |root_dirichlet_alpha|0.25|
# |root_exploration_fraction|0.25|
# |pb_c_base|1000|
# |pb_c_init|1.25|
# |blocks|2|
# |channels|8|
# |reduced_channels|8|
# |resnet_fc_reward_layers|[]|
# |resnet_fc_value_layers|[]|
# |resnet_fc_policy_layers|[]|
# |loss_weight|[0.25,1]|
# |n_training_loop|100|
# |n_episodes|20|
# |n_epochs|400|
# |eval_episodes|10|
# |window_size|1000|
# |batch_size|512|
# |num_unroll_steps|10|
# |td_steps|50|
# |momentum|0.9|
# |lr_init|0.005|
# |lr_decay_rate|1|
# |lr_decay_steps|1000|
# |weight_decay|0.0001|
# |num_cpus|20|
# |visit_softmax_temperature_fn|?|
#
# ### baseline
# |parameters|value|
# |:---|:---|
# |observation_shape|(1,32,32)|
# |action_space_size|4|
# |max_moves|400|
# |support_size_value|20|
# |support_size_reward|1|
# |num_simulations|50|
# |discount|0.997|
# |temperature_threshold|300|
# |root_dirichlet_alpha|1|
# |root_exploration_fraction|0.75|
# |pb_c_base|1000|
# |pb_c_init|1.25|
# |blocks|2|
# |channels|8|
# |reduced_channels|8|
# |resnet_fc_reward_layers|[]|
# |resnet_fc_value_layers|[]|
# |resnet_fc_policy_layers|[]|
# |loss_weight|[0.25,1]|
# |n_training_loop|100|
# |n_episodes|20|
# |n_epochs|400|
# |eval_episodes|10|
# |window_size|1000|
# |batch_size|512|
# |num_unroll_steps|10|
# |td_steps|50|
# |momentum|0.9|
# |lr_init|0.005|
# |lr_decay_rate|1|
# |lr_decay_steps|1000|
# |weight_decay|0.0001|
# |num_cpus|10|
# |visit_softmax_temperature_fn|1|

# %%
#baseline
folders = ['new_section_baseline', 'baseline']
filenames = ['Total reward']
files = [[['Tensorboard_data/{}/1/{}.csv'.format(folder, filename),
         'Tensorboard_data/{}/2/{}.csv'.format(folder, filename),
         'Tensorboard_data/{}/3/{}.csv'.format(folder, filename),]
        for filename in filenames] for folder in folders]

plot_result_csv(folders, filenames, files, max_length = 90, ifsave = False)
